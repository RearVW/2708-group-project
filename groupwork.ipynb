# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import geopandas

# %% [markdown]
# # a)Data input

# %%
df_gas = pd.read_csv('data/TotalHouseholdTownGasConsumptionbyDwellingType2005toJun2021.csv') #hdb gas consumtion
df_gm = pd.read_csv('data/ListingofBuildingEnergyPerformanceData2020.csv') #building with green mark
dg_gm = geopandas.read_file('data/GreenMarkBuildingsGEOJSON.geojson') #green mark building location
dg_ec = geopandas.read_file('data/AverageMonthlyHouseholdElectricityConsumptionbyURAPlanningAreaDwellingType2009.geojson')#hdb energy consumption

# %% [markdown]
# # b)loc function

# %%
pd.set_option('display.max_columns', None)
df_gas.head()
# Out:
#      month     housing_type                        dwelling_type  \
# 0  2005-01   Public Housing                      1-Room / 2-Room
# 1  2005-01   Public Housing                               3-Room
# 2  2005-01   Public Housing                               4-Room
# 3  2005-01   Public Housing                 5-Room and Executive
# 4  2005-01  Private Housing  Private Apartments and Condominiums
#
#    tg_consumption_gwh
# 0                 1.1
# 1                 6.6
# 2                16.0
# 3                17.4
# 4                 5.9

# %%
print(df_gas['dwelling_type'].unique())
# Out:
# ['1-Room / 2-Room' '3-Room' '4-Room' '5-Room and Executive'
#  'Private Apartments and Condominiums' 'Landed Properties' 'Others']

# %%
df_gas.loc[df_gas['housing_type']=='Public Housing',['housing_type','tg_consumption_gwh']].describe()
#summary stat of gas consumption in public housing
# Out:
#        tg_consumption_gwh
# count          784.000000
# mean            10.865306
# std              7.453757
# min              1.000000
# 25%              4.875000
# 50%             12.550000
# 75%             17.900000
# max             31.100000

# %%
df_gas.loc[df_gas['housing_type']=='Private Housing',['housing_type','tg_consumption_gwh']].describe()
#summary stat of gas consumption in private housing
# Out:
#        tg_consumption_gwh
# count          392.000000
# mean             6.139796
# std              5.950611
# min              0.900000
# 25%              0.900000
# 50%              3.550000
# 75%             10.500000
# max             23.600000

# %%
df_gas['year'] = df_gas['month'].str.slice(0, 4)
df_gas.loc[df_gas['year']=='2005',['year','tg_consumption_gwh']].describe()
#summary stat of gas consumption in 2005
# Out:
#        tg_consumption_gwh
# count           84.000000
# mean             6.859524
# std              6.576979
# min              0.500000
# 25%              1.000000
# 50%              6.000000
# 75%             15.625000
# max             17.700000

# %% [markdown]
# # c) tables

# %%
df_gas.groupby('dwelling_type')['tg_consumption_gwh'].describe()
#summary stat of gas consumption for each dwelling type
# Out:
#                                      count       mean       std   min     25%  \
# dwelling_type
# 1-Room / 2-Room                      196.0   1.234184  0.227596   1.0   1.000
# 3-Room                               196.0   6.234694  0.426218   5.8   6.000
# 4-Room                               196.0  17.621429  1.900054  15.2  16.400
# 5-Room and Executive                 196.0  18.370918  1.398542  16.6  17.700
# Landed Properties                    196.0   0.951531  0.077444   0.9   0.900
# Others                               196.0   0.748469  0.509245   0.1   0.200
# Private Apartments and Condominiums  196.0  11.328061  4.108874   5.7   7.975
#
#                                       50%     75%   max
# dwelling_type
# 1-Room / 2-Room                       1.1   1.400   2.1
# 3-Room                                6.2   6.300   9.9
# 4-Room                               17.4  18.400  31.1
# 5-Room and Executive                 18.2  18.725  30.1
# Landed Properties                     0.9   1.000   1.4
# Others                                1.0   1.200   1.4
# Private Apartments and Condominiums  10.5  14.225  23.6

# %%
df_gm.groupby('greenmarkrating')['2020'].describe()
#summary stat of energy performance in 2020 for each green mark rating
#How ever this doesnt show much since the diffrence between each building's gfa within every group can be huge
# Out:
#                  count        mean         std    min       25%      50%  \
# greenmarkrating
# Certified         26.0  228.251923  166.915269  51.40  123.6425  192.710
# Gold              83.0  242.783253  152.925206  37.41  141.5100  200.660
# GoldPlus          60.0  258.098667  142.944963  62.69  159.1350  214.340
# Legislated        22.0  248.104091  168.743369  27.14  120.0375  220.425
# Platinum         126.0  212.362063  141.753956  19.96  127.7425  172.375
#
#                       75%      max
# greenmarkrating
# Certified        261.9200   752.78
# Gold             291.9500   822.63
# GoldPlus         306.6175   712.95
# Legislated       341.5100   684.22
# Platinum         261.8075  1157.40

# %%
df_gm['gfa'] = df_gm['grossfloorarea'].str.replace(',', '').astype(int)
#since original data is considered as string, hv to convert into integer
df_gm.groupby('greenmarkrating')['gfa'].describe()
#Summary stat of the gross floor area for each rating
# Out:
#                  count          mean           std     min       25%      50%  \
# greenmarkrating
# Certified         26.0  41365.115385  85763.740684  5901.0  15293.25  19099.0
# Gold              83.0  41279.240964  60740.572002  5000.0  13546.00  26417.0
# GoldPlus          60.0  41239.183333  33850.351508  5030.0  19421.00  30941.5
# Legislated        22.0  30226.000000  82492.008346   757.0   3305.25   7591.5
# Platinum         126.0  60721.761905  77781.618321  6407.0  21190.00  35968.5
#
#                       75%       max
# greenmarkrating
# Certified        33940.75  452045.0
# Gold             45193.50  490516.0
# GoldPlus         52581.75  170856.0
# Legislated       13627.50  383038.0
# Platinum         70430.50  581511.0

# %% [markdown]
# # d)graphs

# %%
df_gm.head()
# Out:
#            buildingname                      buildingaddress  \
# 0         UNITED SQUARE   101 THOMSON ROAD, SINGAPORE 307591
# 1             HPL HOUSE   50 CUSCADEN ROAD, SINGAPORE 249724
# 2  GRACE GLOBAL RAFFLES  137 MARKET STREET, SINGAPORE 048943
# 3             THE GLOBE   100 CECIL STREET, SINGAPORE 069532
# 4     HIGH STREET PLAZA     77 HIGH STREET, SINGAPORE 179433
#
#           buildingtype mainbuildingfunction buildingsize  yearobtainedtopcsc  \
# 0  Commercial Building    Mixed Development        Large                1984
# 1  Commercial Building               Office        Small                1980
# 2  Commercial Building               Office        Small                2011
# 3  Commercial Building               Office        Small                1993
# 4  Commercial Building               Office        Small                1975
#
#   greenmarkrating  greenmarkyearofaward  \
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2        GoldPlus                2010.0
# 3             NaN                   NaN
# 4             NaN                   NaN
#
#                                     greenmarkversion grossfloorarea  \
# 0                                                NaN         65,947
# 1                                                NaN          7,372
# 2  New Building for Non-Residential buildings (ve...          5,030
# 3                                                NaN          5,824
# 4                                                NaN         10,418
#
#   percentageofairconditionedfloorarea averagemonthlybuildingoccupancyrate  \
# 0                                 93%                                 90%
# 1                                 97%                                 90%
# 2                                 80%                                 97%
# 3                                 70%                                 58%
# 4                                100%                                 90%
#
#    numberofhotelrooms       typeofairconditioningsystem  ageofchiller  \
# 0                 NaN  Water Cooled Chilled Water Plant          12.0
# 1                 NaN                            Others           2.0
# 2                 NaN                            Others           9.0
# 3                 NaN                            Others           0.0
# 4                 NaN  Water Cooled Chilled Water Plant          38.0
#
#    centralisedairconditioningplantefficiency  \
# 0                                       0.68
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                       0.80
#
#    yearoflastchillerplantaudithealthcheck percentageusageofled  \
# 0                                  2019.0                   2%
# 1                                     NaN                  80%
# 2                                     NaN                  20%
# 3                                     NaN                  30%
# 4                                  2020.0                  90%
#
#   installationofsolarpv    2017    2018    2019    2020    gfa
# 0                     N  281.32  276.83  274.91  250.89  65947
# 1                     N  277.93  268.76  264.79  216.27   7372
# 2                     N  171.16  165.32  165.52  115.42   5030
# 3                     N  185.64  168.50  163.46  138.01   5824
# 4                     N  158.37  140.95  149.12  129.54  10418
